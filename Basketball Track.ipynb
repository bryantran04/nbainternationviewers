# %%
import pandas as pd

# %%
event = pd.read_csv("event codes.txt", sep='\t')
gamelineup= pd.read_csv("Game Lineup Data.txt", sep='\t')
playbyplay= pd.read_csv("Play by Play Data Sample.txt", sep='\t')

# %%
event.head()
# Out:
#    Event_Msg_Type  Action_Type                Event_Msg_Type_Description  \
# 0               1            0  Made Shot
# 1               1            1  Made Shot
# 2               1            3  Made Shot
# 3               1            4  Made Shot
# 4               1            5  Made Shot
#
#                     Action_Type_Description
# 0  No Shot
# 1  Jump Shot
# 2  Hook Shot
# 3  Tip Shot
# 4  Layup Shot

# %%
event["Event_Msg_Type_Description"].unique()
# Out:
# array(['Made Shot                               ',
#        'Missed Shot                             ',
#        'Free Throw                              ',
#        'Rebound                                 ',
#        'Turnover                                ',
#        'Foul                                    ',
#        'Violation                               ',
#        'Substitution                            ',
#        'Timeout                                 ',
#        'Jump Ball                               ',
#        'Ejection                                ',
#        'Start Period                            ',
#        'End Period                              ',
#        'No Shot                                 '], dtype=object)

# %%
gamelineup.head(30)
# Out:
#                              Game_id  Period  \
# 0   021fd159b55773fba8157e2090fe0fe2       1
# 1   021fd159b55773fba8157e2090fe0fe2       1
# 2   021fd159b55773fba8157e2090fe0fe2       1
# 3   021fd159b55773fba8157e2090fe0fe2       1
# 4   021fd159b55773fba8157e2090fe0fe2       1
# 5   021fd159b55773fba8157e2090fe0fe2       1
# 6   021fd159b55773fba8157e2090fe0fe2       1
# 7   021fd159b55773fba8157e2090fe0fe2       1
# 8   021fd159b55773fba8157e2090fe0fe2       1
# 9   021fd159b55773fba8157e2090fe0fe2       1
# 10  021fd159b55773fba8157e2090fe0fe2       2
# 11  021fd159b55773fba8157e2090fe0fe2       2
# 12  021fd159b55773fba8157e2090fe0fe2       2
# 13  021fd159b55773fba8157e2090fe0fe2       2
# 14  021fd159b55773fba8157e2090fe0fe2       2
# 15  021fd159b55773fba8157e2090fe0fe2       2
# 16  021fd159b55773fba8157e2090fe0fe2       2
# 17  021fd159b55773fba8157e2090fe0fe2       2
# 18  021fd159b55773fba8157e2090fe0fe2       2
# 19  021fd159b55773fba8157e2090fe0fe2       2
# ...

# %%
len(gamelineup)
# Out:
# 2040

# %%
playbyplay.head()
# Out:
#                             Game_id  Event_Num  Event_Msg_Type  Period  \
# 0  021fd159b55773fba8157e2090fe0fe2          0              12       1
# 1  021fd159b55773fba8157e2090fe0fe2          1              10       1
# 2  021fd159b55773fba8157e2090fe0fe2          2               2       1
# 3  021fd159b55773fba8157e2090fe0fe2          3               4       1
# 4  021fd159b55773fba8157e2090fe0fe2          6               6       1
#
#    WC_Time  PC_Time  Action_Type  Option1  Option2  Option3  \
# 0   546427     7200            0        0        0        0
# 1   546495     7200            0        0        0        0
# 2   546665     7050            1        3        0        0
# 3   546714     6960            0        0        0        0
# 4   546886     6920            4        0        0        0
#
#                             Team_id                           Person1  \
# 0  1473d70e5646a26de3c52aa1abd85b1f  6bcf6c1f8c373d25fca1579bc4464a91
# ...
